# %% [markdown]
# ### Project Goal:

# %% [markdown]
# The goal of this project is to webscrape Meta's newsroom for articles tagged with
#
# * Safety and Expression
# * Combatting Misinformation
# * Data and Privacy

# %% [markdown]
# ### Import packages

# %%
from bs4 import BeautifulSoup
from google.colab import files
import requests
import pandas as pd
import re
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime

# %% [markdown]
# ### Write function to scrape article metadata, text from Meta's newsroom

# %%
def scrape_meta_section(url, page_range):
  data = [ ]
  for i in range(0, page_range):
    request = requests.get(f"{url}/{i}/")
    parser = BeautifulSoup(request.content, "html.parser")

    area_section = parser.find("div", class_="archive-articles-container")
    article_section = area_section.find_all("div", class_="uk-width-3-5 article-excerpt")
    for article in article_section:
      try:
        header = article.find("header", class_="entry-header")
        link_source = header.find("a", href=True)

        article_title = link_source.get_text()
        link = link_source.get("href")

        date_source = header.find("time", class_="entry-date published")
        date_source2 = header.find("time", class_="updated")
        date = date_source.get_text()
        date2 = date_source2.get_text()

        data.append((link, article_title, date, date2))

      except:
        header = article.find("header", class_="entry-header")
        link_source = header.find("a", href=True)

        article_title = link_source.get_text()
        link = link_source.get("href")

        date_source = header.find("time", class_="entry-date published updated")
        date = date_source.get_text()
        date2 = None

        data.append((link, article_title, date, date2))
  return pd.DataFrame(data, columns=["url", "article_title" , "date", "updated_date"])

# %%
def process_row(row, session):
    article_request = session.get(url=row['url'])
    parser = BeautifulSoup(article_request.content, "html.parser")

    author_name, author_pos = "na", "na"
    author = parser.find("div", class_="post-custom_author")
    if author:
        author_text = author.get_text(strip=True)
        match_val = re.match(r"By\s+(.*?),\s*(.*)", author_text)
        if match_val:
            author_name = match_val.group(1)
            author_pos = match_val.group(2)

    text_section = parser.find("div", class_="uk-width-2-3@m article-container")
    paragraphs = text_section.find_all("p") if text_section else []
    plain_text = " ".join([para.get_text(strip=True) for para in paragraphs])

    tag_s = parser.find("div", class_="entry-tags")
    tags_text_cleaned = ""
    if tag_s:
        tags = tag_s.find_all("a")
        tags_text_cleaned = ", ".join([tag.get_text() for tag in tags])

    cat_lst = ["Meta", "Facebook", "Instagram", "WhatsApp"]
    category_text = []
    category_source = parser.find("div", class_="entry-categories")
    if category_source:
        categories = category_source.find_all("a")
        for cat in categories:
            cat_text = cat.get_text()
            if cat_text in cat_lst:
              category_text.append(cat_text)
            else:
              tags_text_cleaned += f", {cat_text}"

    category_text_cleaned = " ".join(category_text)

    return {
        "author": author_name,
        "author_pos": author_pos,
        "text": plain_text,
        "category": category_text_cleaned,
        "tags": tags_text_cleaned,
    }

def append_text_category(dataframe):
    session = requests.Session()
    results = []
    with ThreadPoolExecutor(max_workers=5) as executor:
        results = list(executor.map(lambda row: process_row(row, session), dataframe.to_dict(orient='records')))


    for idx, result in enumerate(results):
        dataframe.at[idx, "author"] = result["author"]
        dataframe.at[idx, "author_pos"] = result["author_pos"]
        dataframe.at[idx, "text"] = result["text"]
        dataframe.at[idx, "category"] = result["category"]
        dataframe.at[idx, "tags"] = result["tags"]

    return dataframe

# %% [markdown]
# ### Scrape metadata section of the Meta blog

# %%
safety_and_expression = scrape_meta_section(url="https://about.fb.com/news/category/safety-and-expression/page/", page_range=22)

# %%
combat_misinfo = scrape_meta_section(url ="https://about.fb.com/news/tag/misinformation/page", page_range=8)

# %%
data_and_privacy = scrape_meta_section(url = "https://about.fb.com/news/category/data-and-privacy/page/", page_range=17)

# %% [markdown]
# ### Scrape article dataset and download as XLSX file

# %%
append_text_category(safety_and_expression)
# Out:
#                                                    url  \
# 0    https://about.fb.com/news/2024/12/2024-global-...
# 1    https://about.fb.com/news/2024/11/cracking-dow...
# 2    https://about.fb.com/news/2024/11/introducing-...
# 3    https://about.fb.com/news/2024/10/testing-comb...
# 4    https://about.fb.com/news/2024/10/instagram-ca...
# ..                                                 ...
# 215  https://about.fb.com/news/2018/12/take-down-in...
# 216  https://about.fb.com/news/2018/12/guardian-fac...
# 217  https://about.fb.com/news/2018/11/content-stan...
# 218  https://about.fb.com/news/2018/11/enforcing-ou...
# 219  https://about.fb.com/news/2018/11/inside-feed-...
#
#                                          article_title               date  \
# 0    What We Saw on Our Platforms During 2024’s Glo...   December 3, 2024
# 1    Cracking Down on Organized Crime Behind Scam C...  November 21, 2024
# 2    Reshape Your Instagram With a Recommendations ...  November 19, 2024
# 3    Testing New Ways to Combat Scams and Help Rest...   October 21, 2024
# 4    Our New Education Campaign to Help Protect Tee...   October 17, 2024
# ..                                                 ...                ...
# 215  Taking Down Coordinated Inauthentic Behavior i...  December 20, 2018
# 216  Responding to The Guardian: A Fact-Check on Fa...  December 13, 2018
# 217                       Product Policy Forum Minutes  November 15, 2018
# 218  How Are We Doing at Enforcing Our Community St...  November 15, 2018
# 219  Promoting Safety with Policy, Product and Oper...  November 15, 2018
#
#           updated_date author author_pos  \
# 0     December 3, 2024     na         na
# 1      January 6, 2025     na         na
# 2    November 19, 2024     na         na
# 3    December 10, 2024     na         na
# 4    December 10, 2024     na         na
# ..                 ...    ...        ...
# 215     March 24, 2021     na         na
# 216      June 22, 2020     na         na
# 217   January 26, 2022     na         na
# 218  December 13, 2019     na         na
# 219    August 29, 2022     na         na
#
#                                                   text            category  \
# 0    The recent presidential election in the United...                Meta
# 1    Every day, criminals target people across the ...                Meta
# 2    We want to make sure everyone on Instagram – e...           Instagram
# 3    We know security matters, and that includes be...  Facebook Instagram
# 4    Sextortion is a horrific crime, where financia...           Instagram
# ..                                                 ...                 ...
# 215  ByNathaniel Gleicher, Head of Cybersecurity Po...                Meta
# 216  ByMeredith Carden,Head of News Integrity Partn...                Meta
# 217  We recognize how important it is for Facebook ...                Meta
# 218  ByGuy Rosen, VP of Product Management People w...                Meta
# 219  What is and isn’t allowed on Facebook? The ans...                Meta
#
#                                                   tags
# 0    Artificial Intelligence and Machine Learning, ...
# 1    Safety, Scams, Security News, Well-Being, Inte...
# 2    Safety, Well-Being, Product News, Safety and E...
# 3    Creators, Product News, Safety, Scams, Public ...
# 4    Safety, Scams, Well-Being, Public Policy, Safe...
# ..                                                 ...
# 215  Community Standards and Enforcement, Coordinat...
# 216  Combating Misinformation, Community Standards ...
# 217  Community Standards and Enforcement, Public Po...
# 218  Community Standards and Enforcement, Community...
# 219  Community Standards and Enforcement, Inside Fe...
#
# [220 rows x 9 columns]

# %%
append_text_category(combat_misinfo)
# Out:
#                                                   url  \
# 0   https://about.fb.com/news/2024/12/2024-global-...
# 1   https://about.fb.com/news/2022/11/metas-progre...
# 2   https://about.fb.com/news/2022/08/how-meta-is-...
# 3   https://about.fb.com/news/2022/07/oversight-bo...
# 4   https://about.fb.com/news/2022/07/how-metas-pr...
# ..                                                ...
# 75  https://about.fb.com/news/2018/10/removing-ina...
# 76  https://about.fb.com/news/2018/09/expanding-fa...
# 77  https://about.fb.com/news/2018/06/hard-questio...
# 78  https://about.fb.com/news/2018/05/facing-facts...
# 79  https://about.fb.com/news/2018/05/inside-feed-...
#
#                                         article_title                date  \
# 0   What We Saw on Our Platforms During 2024’s Glo...    December 3, 2024
# 1    Sharing Our Progress on Combating Climate Change    November 6, 2022
# 2   How Meta Is Preparing for Brazil’s 2022 Elections     August 12, 2022
# 3   Meta Asks Oversight Board to Advise on COVID-1...       July 26, 2022
# 4   How Meta is Preparing for Kenya’s 2022 General...       July 20, 2022
# ..                                                ...                 ...
# 75  Removing Additional Inauthentic Activity from ...    October 11, 2018
# 76       Expanding Fact-Checking to Photos and Videos  September 13, 2018
# 77   How Is Facebook’s Fact-Checking Program Working?       June 14, 2018
# 78  Facing Facts: Facebook’s Fight Against Misinfo...        May 23, 2018
# 79  PBS Wraps 4-Part Series on ‘Junk News,’ Featur...        May 22, 2018
#
#          updated_date        author  \
# 0    December 3, 2024            na
# 1   November 11, 2022            na
# 2     August 16, 2022            na
# 3       June 16, 2023    Nick Clegg
# 4       July 20, 2022  Mercy Ndegwa
# ..                ...           ...
# 75      June 22, 2020            na
# 76      June 22, 2020            na
# 77      June 22, 2020            na
# 78      June 22, 2020            na
# 79      June 22, 2020            na
#
#                                          author_pos  \
# 0                                                na
# 1                                                na
# 2                                                na
# 3                         President, Global Affairs
# 4   Director of Public Policy East & Horn of Africa
# ..                                              ...
# 75                                               na
# 76                                               na
# 77                                               na
# 78                                               na
# 79                                               na
#
#                                                  text       category  \
# 0   The recent presidential election in the United...           Meta
# 1   Update on November 11, 2022 at 8:00AM PT: Meta...  Facebook Meta
# 2   Update on August 16, 2022 at 10:30AM PT: As pa...           Meta
# 3   Update on June 16, 2023 at 6:00AM PT: Today, w...           Meta
# 4   Today, we’re sharing an update on our work to ...           Meta
# ..                                                ...            ...
# 75  ByNathaniel Gleicher, Head of Cybersecurity Po...           Meta
# 76  By Antonia Woodford, Product Manager We know t...       Facebook
# 77  Hard Questions isa seriesfrom Facebook that ad...           Meta
# 78  ByJohn Hegeman, Head of News Feed Over the las...           Meta
# 79  On May 16, PBS NewsHour aired the fourth and f...           Meta
#
#                                                  tags
# 0   Artificial Intelligence and Machine Learning, ...
# 1   Climate, Combating Misinformation, Sustainability
# 2   Combating Misinformation, Elections, Election ...
# 3   Combating Misinformation, COVID-19 Response, H...
# 4   Combating Hate Speech, Combating Misinformatio...
# ..                                                ...
# 75  Combating Misinformation, Community Standards ...
# 76  Combating Misinformation, False News, Photos, ...
# 77  Combating Misinformation, False News, Hard Que...
# 78  Combating Misinformation, False News, Company ...
# 79  Combating Misinformation, False News, Integrit...
#
# [80 rows x 9 columns]

# %%
append_text_category(data_and_privacy)
# Out:
#                                                    url  \
# 0    https://about.fb.com/news/2024/03/end-to-end-e...
# 1    https://about.fb.com/news/2024/01/investing-in...
# 2    https://about.fb.com/news/2023/12/default-end-...
# 3    https://about.fb.com/news/2023/11/new-tools-to...
# 4    https://about.fb.com/news/2023/10/collaboratin...
# ..                                                 ...
# 163  https://about.fb.com/news/2019/02/addressing-c...
# 164  https://about.fb.com/news/2019/01/a-discussion...
# 165  https://about.fb.com/news/2019/01/data-privacy...
# 166  https://about.fb.com/news/2019/01/designing-se...
# 167  https://about.fb.com/news/2019/01/what-kind-of...
#
#                                          article_title               date  \
# 0         End-to-End Encryption on Messenger Explained     March 28, 2024
# 1                                 Investing In Privacy   January 25, 2024
# 2    Launching Default End-to-End Encryption on Mes...   December 6, 2023
# 3            New Tools to Support Independent Research  November 21, 2023
# 4    Feedback Is a Gift: How We Collaborate to Buil...    October 5, 2023
# ..                                                 ...                ...
# 163  What Is Facebook Doing to Address the Challeng...   February 4, 2019
# 164                       A Discussion with Nick Clegg   January 28, 2019
# 165                      Marking Data Privacy Day 2019   January 27, 2019
# 166                    Designing Security for Billions   January 25, 2019
# 167                  What Kind of Internet Do We Want?   January 20, 2019
#
#            updated_date           author                      author_pos  \
# 0        March 28, 2024               na                              na
# 1     February 29, 2024    Michel Protti  Chief Privacy Officer, Product
# 2     December 11, 2023  Loredana Crisan               Head of Messenger
# 3    September 26, 2024       Nick Clegg       President, Global Affairs
# 4      January 24, 2024        Erin Egan   Chief Privacy Officer, Policy
# ..                  ...              ...                             ...
# 163   November 11, 2019               na                              na
# 164    January 31, 2021               na                              na
# 165    November 7, 2019               na                              na
# 166     August 29, 2022               na                              na
# 167    January 31, 2021               na                              na
#
#                                                   text category  \
# 0    In December, we startedrolling out default end...
# 1    Update on February 29, 2024 at 9:30AM PT Learn...     Meta
# 2    Today I’m delighted to announce that we are ro...
# 3    Update on September 26, 2024 at 9:00AM PT: Thr...     Meta
# 4    This week Meta hosted nearly 100 privacy acade...     Meta
# ..                                                 ...      ...
# 163  The most frequently asked questions we receive...     Meta
# 164  Vice President of Global Affairs and Communica...     Meta
# 165  ByErin Egan, Chief Privacy Officer, Policy Mon...     Meta
# 166  By Collin Greene, Manager of Product Security ...     Meta
# 167  BySheryl Sandberg, Chief Operating Officer Wha...     Meta
#
#                                                   tags
# 0          , Data and Privacy, Messenger, Product News
# 1     Privacy Matters, Data and Privacy, Public Policy
# 2          , Data and Privacy, Messenger, Product News
# 3                                   , Data and Privacy
# 4    Privacy Conversations, Privacy Matters, Data a...
# ..                                                 ...
# 163  Ads and Pages Transparency, Community Standard...
# 164  Ads and Pages Transparency, Community Standard...
# 165  Controls, Resources, Data and Privacy, Public ...
# 166  Security News, Data and Privacy, Inside Feed, ...
# 167  Perspectives, Security News, Speeches, Data an...
#
# [168 rows x 9 columns]

# %%
safety_and_expression['date'] = safety_and_expression['date'].map(lambda x: datetime.strptime(x, "%B %d, %Y").strftime("%Y-%m-%d"))
safety_and_expression['updated_date'] = safety_and_expression['updated_date'].map(lambda x: datetime.strptime(x, "%B %d, %Y").strftime("%Y-%m-%d") if x else None)

# %%
combat_misinfo['date'] = combat_misinfo['date'].map(lambda x: datetime.strptime(x, "%B %d, %Y").strftime("%Y-%m-%d"))
combat_misinfo['updated_date'] = combat_misinfo['updated_date'].map(lambda x: datetime.strptime(x, "%B %d, %Y").strftime("%Y-%m-%d") if x else None)

# %%
data_and_privacy['date'] = data_and_privacy['date'].map(lambda x: datetime.strptime(x, "%B %d, %Y").strftime("%Y-%m-%d"))
data_and_privacy['updated_date'] = data_and_privacy['updated_date'].map(lambda x: datetime.strptime(x, "%B %d, %Y").strftime("%Y-%m-%d") if x else None)

# %%
safety_and_expression.to_excel('meta_safety_expression.xlsx', index=False)
files.download('meta_safety_expression.xlsx')

# %%
combat_misinfo.to_excel('meta_content_misinfo.xlsx', index=False)
files.download('meta_content_misinfo.xlsx')

# %%
data_and_privacy.to_excel('meta_data_privacy.xlsx', index=False)
files.download("meta_data_privacy.xlsx")
